# %% [markdown]
# Setting up work environment

# %%
from __future__ import print_function

import pylab as pl
from scipy.optimize import curve_fit, minimize
    
# %pylab inline
import numpy as np
import matplotlib.pyplot as pt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Normal (Gaussian) Distribution

# %%
#GENERATE 100 samples of different sizes N (N>10 & N<2000) from each of 5 different distributions (500 samples in total)
#distribution 1: gaussian
dict = {}
# d1 is an empty disctionary
dict['gaussian'] = np.random.normal(loc=0.0, scale=1.0, size=100)
# d1 now is a dictionary with one object: an array by the key 'gaussian'
pl.hist(dict['gaussian'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
#show mean and standard deviation for above distribution
print ("Gaussian mean: %.2f, standard deviation: %.2f"%(dict['gaussian'].mean(), dict['gaussian'].std()))
# Out:
# Gaussian mean: -0.04, standard deviation: 1.02

# %% [markdown]
# Repeat process for 100 distributions:

# %%
#create array
d1_100 = np.linspace(5,2000,100)
print (d1_100, d1_100.shape)
# Out:
# [    5.            25.15151515    45.3030303     65.45454545    85.60606061
#    105.75757576   125.90909091   146.06060606   166.21212121   186.36363636
#    206.51515152   226.66666667   246.81818182   266.96969697   287.12121212
#    307.27272727   327.42424242   347.57575758   367.72727273   387.87878788
#    408.03030303   428.18181818   448.33333333   468.48484848   488.63636364
#    508.78787879   528.93939394   549.09090909   569.24242424   589.39393939
#    609.54545455   629.6969697    649.84848485   670.           690.15151515
#    710.3030303    730.45454545   750.60606061   770.75757576   790.90909091
#    811.06060606   831.21212121   851.36363636   871.51515152   891.66666667
#    911.81818182   931.96969697   952.12121212   972.27272727   992.42424242
#   1012.57575758  1032.72727273  1052.87878788  1073.03030303  1093.18181818
#   1113.33333333  1133.48484848  1153.63636364  1173.78787879  1193.93939394
# ...

# %%
#redefining the dictionary
dict['gaussian'] = {} 

#create for loop 
for n in d1_100:
    dict['gaussian'][n] = np.random.normal(loc=0.0, scale=1.0, size=100)
#plot means of 100 distributions
dict['gaussian']['means'] = {}
d1_ax = pl.figure(figsize=(10,6)).add_subplot(111)

for x in dict['gaussian']:
    if not type(x) == str:
        dict['gaussian']['means'][x] = dict['gaussian'][x].mean()
        #and plot it
        d1_ax.plot(x, d1['gaussian']['means'][x], 'o')
        d1_ax.set_xlabel('sample size', fontsize=18)
        d1_ax.set_ylabel('sample mean', fontsize=18)
        d1_ax.set_title('Gaussian', fontsize=18)
        d1_ax.plot([min(d1_100), max(d1_100)],[0,0], 'k')

# %%
# plot histogram of all means
d1_means = list(dict['gaussian']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(d1_means,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# Distribution 2: Chi Squared

# %%
#distribution 2: chisq
d2mean = 100
df = d2mean


dict['chisq'] = np.random.chisquare(df, size=100)
# d2 now is a dictionary with one object: an array by the key 'chisq'

pl.hist(dict['chisq'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
print ("Chisq mean: %.2f, standard deviation: %.2f"%(dict['chisq'].mean(), dict['chisq'].std()))
# Out:
# Chisq mean: 99.50, standard deviation: 13.49

# %%
#create array
d2_100 = np.linspace(5,2000,100)
print (d2_100, d2_100.shape)
# Out:
# [    5.            25.15151515    45.3030303     65.45454545    85.60606061
#    105.75757576   125.90909091   146.06060606   166.21212121   186.36363636
#    206.51515152   226.66666667   246.81818182   266.96969697   287.12121212
#    307.27272727   327.42424242   347.57575758   367.72727273   387.87878788
#    408.03030303   428.18181818   448.33333333   468.48484848   488.63636364
#    508.78787879   528.93939394   549.09090909   569.24242424   589.39393939
#    609.54545455   629.6969697    649.84848485   670.           690.15151515
#    710.3030303    730.45454545   750.60606061   770.75757576   790.90909091
#    811.06060606   831.21212121   851.36363636   871.51515152   891.66666667
#    911.81818182   931.96969697   952.12121212   972.27272727   992.42424242
#   1012.57575758  1032.72727273  1052.87878788  1073.03030303  1093.18181818
#   1113.33333333  1133.48484848  1153.63636364  1173.78787879  1193.93939394
# ...

# %%
dict['chisq'] = {} 

for n in d2_100:
    dict['chisq'][n] = np.random.chisquare(df, size=100)

dict['chisq']['means'] = {}
d2_ax = pl.figure(figsize=(10,6)).add_subplot(111)

for x in dict['chisq']:
    if not type(x) == str:
        dict['chisq']['means'][x] = dict['chisq'][x].mean()
        
        d2_ax.plot(x, dict['chisq']['means'][x], 'o')
        d2_ax.set_xlabel('sample size', fontsize=18)
        d2_ax.set_ylabel('sample mean', fontsize=18)
        d2_ax.set_title('Chi Squared', fontsize=18)
        d2_ax.plot([min(d2_100), max(d2_100)],[df,df], 'k')

# %%
# plot histogram of all means
d2_means = list(dict['chisq']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(d2_means,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# Distribution 3: Poisson

# %%
#distribution 3: pois

dict['pois'] = np.random.poisson(lam=1.0, size=100)
# 'pois' is now a key in the dictionary

pl.hist(dict['pois'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
print ("Poisson mean: %.2f, standard deviation: %.2f"%(dict['pois'].mean(), dict['pois'].std()))
# Out:
# Poisson mean: 0.99, standard deviation: 1.03

# %%
#create array
d3_100 = np.linspace(5,2000,100)
print (d3_100, d3_100.shape)
# Out:
# [    5.            25.15151515    45.3030303     65.45454545    85.60606061
#    105.75757576   125.90909091   146.06060606   166.21212121   186.36363636
#    206.51515152   226.66666667   246.81818182   266.96969697   287.12121212
#    307.27272727   327.42424242   347.57575758   367.72727273   387.87878788
#    408.03030303   428.18181818   448.33333333   468.48484848   488.63636364
#    508.78787879   528.93939394   549.09090909   569.24242424   589.39393939
#    609.54545455   629.6969697    649.84848485   670.           690.15151515
#    710.3030303    730.45454545   750.60606061   770.75757576   790.90909091
#    811.06060606   831.21212121   851.36363636   871.51515152   891.66666667
#    911.81818182   931.96969697   952.12121212   972.27272727   992.42424242
#   1012.57575758  1032.72727273  1052.87878788  1073.03030303  1093.18181818
#   1113.33333333  1133.48484848  1153.63636364  1173.78787879  1193.93939394
# ...

# %%
dict['pois'] = {} 

for n in d3_100:
    dict['pois'][n] = np.random.poisson(lam=1.0, size=100)

dict['pois']['means'] = {}
d3_ax = pl.figure(figsize=(10,6)).add_subplot(111)

for x in dict['pois']:
    if not type(x) == str:
        dict['pois']['means'][x] = dict['pois'][x].mean()
        #and plot it
        d3_ax.plot(x, dict['pois']['means'][x], 'o')
        d3_ax.set_xlabel('sample size', fontsize=18)
        d3_ax.set_ylabel('sample mean', fontsize=18)
        d3_ax.set_title('Poisson', fontsize=18)
        d3_ax.plot([min(d3_100), max(d3_100)],[1,1], 'k')

# %%
# plot histogram of all means
d3_means = list(dict['pois']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(d3_means,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# Distribution 4: Binomial

# %%
#distribution 4: binomial
p = .5
n = 100


dict['bi'] = np.random.binomial(n, p, size=100)

# 'bi' is now the keyword in the dictionary for binomial distribution

pl.hist(dict['bi'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %%
print ("Binomial mean: %.2f, standard deviation: %.2f"%(dict['bi'].mean(), dict['bi'].std()))
# Out:
# Binomial mean: 49.72, standard deviation: 4.56

# %%
#create array
d4_100 = np.linspace(5,2000,100)
print (d4_100, d4_100.shape)
# Out:
# [    5.            25.15151515    45.3030303     65.45454545    85.60606061
#    105.75757576   125.90909091   146.06060606   166.21212121   186.36363636
#    206.51515152   226.66666667   246.81818182   266.96969697   287.12121212
#    307.27272727   327.42424242   347.57575758   367.72727273   387.87878788
#    408.03030303   428.18181818   448.33333333   468.48484848   488.63636364
#    508.78787879   528.93939394   549.09090909   569.24242424   589.39393939
#    609.54545455   629.6969697    649.84848485   670.           690.15151515
#    710.3030303    730.45454545   750.60606061   770.75757576   790.90909091
#    811.06060606   831.21212121   851.36363636   871.51515152   891.66666667
#    911.81818182   931.96969697   952.12121212   972.27272727   992.42424242
#   1012.57575758  1032.72727273  1052.87878788  1073.03030303  1093.18181818
#   1113.33333333  1133.48484848  1153.63636364  1173.78787879  1193.93939394
# ...

# %%
dict['bi'] = {} 
newp = .5
newn = 100
for n in d4_100:
    dict['bi'][n] = np.random.binomial(newn, newp, size=100)

dict['bi']['means'] = {}
d4_ax = pl.figure(figsize=(10,6)).add_subplot(111)

for x in dict['bi']:
    if not type(x) == str:
        dict['bi']['means'][x] = dict['bi'][x].mean()
        #and plot it
        d4_ax.plot(x, d4['bi']['means'][x], 'o')
        d4_ax.set_xlabel('sample size', fontsize=18)
        d4_ax.set_ylabel('sample mean', fontsize=18)
        d4_ax.set_title('Binomial', fontsize=18)
        d4_ax.plot([min(d4_100), max(d4_100)],[50,50], 'k')

# %%
# plot histogram of all means
d4_means = list(dict['bi']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(d4_means,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# Distribution 5: Geometric

# %%
#distribution 5: Geometric
p5 = 0.01
std = np.sqrt((1-p5)/(p5**2))
mean = 1/p5

dict['geo'] = np.random.geometric(p5,size = n)

#new key for this dictionary for geometric distribution

pl.hist(dict['geo'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')
# Out:
# /opt/rh/anaconda/root/lib/python2.7/site-packages/ipykernel/__main__.py:6: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
print ("Geometric mean: %.2f, standard deviation: %.2f"%(dict['geo'].mean(), dict['geo'].std()))
# Out:
# Geometric mean: 100.03, standard deviation: 96.25

# %%
#create array
d5_100 = np.linspace(5,2000,100)
print (d5_100, d5_100.shape)
# Out:
# [    5.            25.15151515    45.3030303     65.45454545    85.60606061
#    105.75757576   125.90909091   146.06060606   166.21212121   186.36363636
#    206.51515152   226.66666667   246.81818182   266.96969697   287.12121212
#    307.27272727   327.42424242   347.57575758   367.72727273   387.87878788
#    408.03030303   428.18181818   448.33333333   468.48484848   488.63636364
#    508.78787879   528.93939394   549.09090909   569.24242424   589.39393939
#    609.54545455   629.6969697    649.84848485   670.           690.15151515
#    710.3030303    730.45454545   750.60606061   770.75757576   790.90909091
#    811.06060606   831.21212121   851.36363636   871.51515152   891.66666667
#    911.81818182   931.96969697   952.12121212   972.27272727   992.42424242
#   1012.57575758  1032.72727273  1052.87878788  1073.03030303  1093.18181818
#   1113.33333333  1133.48484848  1153.63636364  1173.78787879  1193.93939394
# ...

# %%
dict['geo'] = {} 

for n in d5_100:
    dict['geo'][n] = np.random.geometric(p5,size = n)

dict['geo']['means'] = {}
d5_ax = pl.figure(figsize=(10,6)).add_subplot(111)

for x in dict['geo']:
    if not type(x) == str:
        dict['geo']['means'][x] = dict['geo'][x].mean()
        #and plot it
        d5_ax.plot(x, dict['geo']['means'][x], 'o')
        d5_ax.set_xlabel('sample size', fontsize=18)
        d5_ax.set_ylabel('sample mean', fontsize=18)
        d5_ax.set_title('Geometric', fontsize=18)
        d5_ax.plot([min(d5_100), max(d5_100)],[mean,mean], 'k')
# Out:
# /opt/rh/anaconda/root/lib/python2.7/site-packages/ipykernel/__main__.py:4: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
# plot histogram of all means
d5_means = list(dict['geo']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(d5_means,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# ## Plot all 500 samples in one histogram:

# %%
all500 = []
for dist in dict.keys():
    allvalues = all500 + list(dict[dict.keys()[0]]["means"].values())
pl.figure(figsize=(10,10))
result = pl.hist(allvalues,bins=50)
pl.xlabel('Sample Mean', fontsize = 14)
pl.ylabel('N', fontsize = 14)
pl.title('Distribution of All 500 Sample Means', fontsize = 18)
